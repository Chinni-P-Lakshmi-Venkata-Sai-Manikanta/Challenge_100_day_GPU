# %%
# %%writefile LayerNorm.cu
# #include <iostream>
# #include <cmath>
# #include <cuda_runtime.h>
#
# __global__ void LayerNorm(const float* A, float* B, int rows, int cols) {
#     // Calculate row index
#     int row = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if (row < rows) {
#         // Use shared memory for row-wise computation
#         extern __shared__ float shared[];
#         float* row_data = shared;
#
#         // Copy row data to shared memory
#         for (int col = threadIdx.y; col < cols; col += blockDim.y) {
#             row_data[col] = A[row * cols + col];
#             printf("Row %d, Thread Y %d, Copying A[%d] to shared[%d]: %.2f\n", row, threadIdx.y, row * cols + col, col, row_data[col]);
#         }
#         __syncthreads();
#
#         // Compute mean
#         float mean = 0.0f;
#         for (int col = 0; col < cols; col++) {
#             mean += row_data[col];
#             printf("Row %d, Thread X %d, Calculating mean: adding %.2f, current mean: %.2f\n", row, threadIdx.x, row_data[col], mean);
#         }
#         mean /= cols;
#         printf("Row %d, Thread X %d, Final mean: %.2f\n", row, threadIdx.x, mean);
#
#         // Compute variance
#         float variance = 0.0f;
#         for (int col = 0; col < cols; col++) {
#             variance += (row_data[col] - mean) * (row_data[col] - mean);
#             printf("Row %d, Thread X %d, Calculating variance: adding (%.2f - %.2f)^2, current variance: %.2f\n", row, threadIdx.x, row_data[col], mean, variance);
#         }
#         variance /= cols;
#         float stddev = sqrtf(variance + 1e-7);
#         printf("Row %d, Thread X %d, Final variance: %.2f, Stddev: %.2f\n", row, threadIdx.x, variance, stddev);
#
#
#         // Normalize
#         for (int col = threadIdx.y; col < cols; col += blockDim.y) {
#             B[row * cols + col] = (row_data[col] - mean) / stddev;
#             printf("Row %d, Thread Y %d, Normalizing shared[%d]: (%.2f - %.2f) / %.2f = %.2f\n", row, threadIdx.y, col, row_data[col], mean, stddev, B[row * cols + col]);
#         }
#     }
# }
#
# int main() {
#     const int rows = 10, cols = 10;
#     float *A, *B;
#
#     // Allocate host memory
#     A = (float*)malloc(rows * cols * sizeof(float));
#     B = (float*)malloc(rows * cols * sizeof(float));
#
#     // Initialize input matrix
#     for (int i = 0; i < rows; i++) {
#         for (int j = 0; j < cols; j++) {
#             A[i * cols + j] = static_cast<float>(rand()) / RAND_MAX;
#         }
#     }
#
#     // Allocate device memory
#     float *d_a, *d_b;
#     cudaMalloc(&d_a, rows * cols * sizeof(float));
#     cudaMalloc(&d_b, rows * cols * sizeof(float));
#
#     // Copy data to device
#     cudaMemcpy(d_a, A, rows * cols * sizeof(float), cudaMemcpyHostToDevice);
#
#     // Launch kernel
#     int blocksize_x = 256;
#     int blocksize_y = 1; // Adjust blocksize_y based on cols
#     dim3 blockDim(blocksize_x, blocksize_y);
#     dim3 gridDim((rows + blocksize_x - 1) / blocksize_x);
#
#     size_t shared_memory_size = cols * sizeof(float);
#     LayerNorm<<<gridDim, blockDim, shared_memory_size>>>(d_a, d_b, rows, cols);
#
#     // Synchronize device
#     cudaDeviceSynchronize();
#
#     // Copy result back to host
#     cudaMemcpy(B, d_b, rows * cols * sizeof(float), cudaMemcpyDeviceToHost);
#
#     // Print results
#     printf("A:\n");
#     for (int i = 0; i < rows; i++) {
#         for (int j = 0; j < cols; j++) {
#             printf("%.2f ", A[i * cols + j]);
#         }
#         printf("\n");
#     }
#
#     printf("\nB:\n");
#     for (int i = 0; i < rows; i++) {
#         for (int j = 0; j < cols; j++) {
#             printf("%.2f ", B[i * cols + j]);
#         }
#         printf("\n");
#     }
#
#     // Free memory
#     cudaFree(d_a);
#     cudaFree(d_b);
#     free(A);
#     free(B);
#
#     return 0;
# }
# Out:
# Writing LayerNorm.cu

# %%
# Compile with the specified architecture
# !nvcc LayerNorm.cu -o LayerNorm -gencode arch=compute_75,code=sm_75

# Run the executable
# !./LayerNorm
# Out:
# Row 0, Thread Y 0, Copying A[0] to shared[0]: 0.84
# Row 1, Thread Y 0, Copying A[10] to shared[0]: 0.48
# Row 2, Thread Y 0, Copying A[20] to shared[0]: 0.02
# Row 3, Thread Y 0, Copying A[30] to shared[0]: 0.51
# Row 4, Thread Y 0, Copying A[40] to shared[0]: 0.53
# Row 5, Thread Y 0, Copying A[50] to shared[0]: 0.53
# Row 6, Thread Y 0, Copying A[60] to shared[0]: 0.24
# Row 7, Thread Y 0, Copying A[70] to shared[0]: 0.53
# Row 8, Thread Y 0, Copying A[80] to shared[0]: 0.69
# Row 9, Thread Y 0, Copying A[90] to shared[0]: 0.96
# Row 0, Thread Y 0, Copying A[1] to shared[1]: 0.39
# Row 1, Thread Y 0, Copying A[11] to shared[1]: 0.63
# Row 2, Thread Y 0, Copying A[21] to shared[1]: 0.24
# Row 3, Thread Y 0, Copying A[31] to shared[1]: 0.84
# Row 4, Thread Y 0, Copying A[41] to shared[1]: 0.77
# Row 5, Thread Y 0, Copying A[51] to shared[1]: 0.09
# Row 6, Thread Y 0, Copying A[61] to shared[1]: 0.97
# Row 7, Thread Y 0, Copying A[71] to shared[1]: 0.04
# Row 8, Thread Y 0, Copying A[81] to shared[1]: 0.17
# Row 9, Thread Y 0, Copying A[91] to shared[1]: 0.59
# Row 0, Thread Y 0, Copying A[2] to shared[2]: 0.78
# Row 1, Thread Y 0, Copying A[12] to shared[2]: 0.36
# Row 2, Thread Y 0, Copying A[22] to shared[2]: 0.14
# Row 3, Thread Y 0, Copying A[32] to shared[2]: 0.61
# Row 4, Thread Y 0, Copying A[42] to shared[2]: 0.40
# Row 5, Thread Y 0, Copying A[52] to shared[2]: 0.19
# Row 6, Thread Y 0, Copying A[62] to shared[2]: 0.90
# Row 7, Thread Y 0, Copying A[72] to shared[2]: 0.44
# Row 8, Thread Y 0, Copying A[82] to shared[2]: 0.44
# Row 9, Thread Y 0, Copying A[92] to shared[2]: 0.66
# Row 0, Thread Y 0, Copying A[3] to shared[3]: 0.80
# Row 1, Thread Y 0, Copying A[13] to shared[3]: 0.51
# Row 2, Thread Y 0, Copying A[23] to shared[3]: 0.80
# Row 3, Thread Y 0, Copying A[33] to shared[3]: 0.30
# Row 5, Thread X 5, Calculating mean: adding 0.34, current mean: 4.26
# Row 6, Thread X 6, Calculating mean: adding 0.34, current mean: 4.26
# Row 7, Thread X 7, Calculating mean: adding 0.34, current mean: 4.26
# Row 8, Thread X 8, Calculating mean: adding 0.34, current mean: 4.26
# Row 9, Thread X 9, Calculating mean: adding 0.34, current mean: 4.26
# Row 0, Thread X 0, Calculating mean: adding 0.77, current mean: 5.03
# Row 1, Thread X 1, Calculating mean: adding 0.77, current mean: 5.03
# Row 2, Thread X 2, Calculating mean: adding 0.77, current mean: 5.03
# Row 3, Thread X 3, Calculating mean: adding 0.77, current mean: 5.03
# Row 4, Thread X 4, Calculating mean: adding 0.77, current mean: 5.03
# Row 5, Thread X 5, Calculating mean: adding 0.77, current mean: 5.03
# Row 6, Thread X 6, Calculating mean: adding 0.77, current mean: 5.03
# Row 7, Thread X 7, Calculating mean: adding 0.77, current mean: 5.03
# Row 8, Thread X 8, Calculating mean: adding 0.77, current mean: 5.03
# Row 9, Thread X 9, Calculating mean: adding 0.77, current mean: 5.03
# Row 0, Thread X 0, Calculating mean: adding 0.28, current mean: 5.31
# Row 1, Thread X 1, Calculating mean: adding 0.28, current mean: 5.31
# Row 2, Thread X 2, Calculating mean: adding 0.28, current mean: 5.31
# Row 3, Thread X 3, Calculating mean: adding 0.28, current mean: 5.31
# Row 4, Thread X 4, Calculating mean: adding 0.28, current mean: 5.31
# Row 5, Thread X 5, Calculating mean: adding 0.28, current mean: 5.31
# Row 6, Thread X 6, Calculating mean: adding 0.28, current mean: 5.31
# Row 7, Thread X 7, Calculating mean: adding 0.28, current mean: 5.31
# Row 8, Thread X 8, Calculating mean: adding 0.28, current mean: 5.31
# Row 9, Thread X 9, Calculating mean: adding 0.28, current mean: 5.31
# Row 0, Thread X 0, Calculating mean: adding 0.55, current mean: 5.86
# Row 1, Thread X 1, Calculating mean: adding 0.55, current mean: 5.86
# Row 2, Thread X 2, Calculating mean: adding 0.55, current mean: 5.86
# Row 3, Thread X 3, Calculating mean: adding 0.55, current mean: 5.86
# Row 4, Thread X 4, Calculating mean: adding 0.55, current mean: 5.86
# Row 5, Thread X 5, Calculating mean: adding 0.55, current mean: 5.86
# Row 6, Thread X 6, Calculating mean: adding 0.55, current mean: 5.86
# Row 7, Thread X 7, Calculating mean: adding 0.55, current mean: 5.86
# Row 8, Thread X 8, Calculating mean: adding 0.55, current mean: 5.86
# Row 9, Thread X 9, Calculating mean: adding 0.55, current mean: 5.86
# Row 0, Thread X 0, Final mean: 0.59
# Row 1, Thread X 1, Final mean: 0.59
# Row 2, Thread X 2, Final mean: 0.59
# Row 3, Thread X 3, Final mean: 0.59
# Row 4, Thread X 4, Final mean: 0.59
# Row 5, Thread X 5, Final mean: 0.59
# Row 6, Thread X 6, Final mean: 0.59
# Row 7, Thread X 7, Final mean: 0.59
# Row 8, Thread X 8, Final mean: 0.59
# Row 9, Thread X 9, Final mean: 0.59
# Row 0, Thread X 0, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 1, Thread X 1, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 2, Thread X 2, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 3, Thread X 3, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 4, Thread X 4, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 5, Thread X 5, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 6, Thread X 6, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 7, Thread X 7, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 8, Thread X 8, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 9, Thread X 9, Calculating variance: adding (0.84 - 0.59)^2, current variance: 0.06
# Row 0, Thread X 0, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 1, Thread X 1, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 2, Thread X 2, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 3, Thread X 3, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 4, Thread X 4, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 5, Thread X 5, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 6, Thread X 6, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 7, Thread X 7, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 8, Thread X 8, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 9, Thread X 9, Calculating variance: adding (0.39 - 0.59)^2, current variance: 0.10
# Row 0, Thread X 0, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 1, Thread X 1, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 2, Thread X 2, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 3, Thread X 3, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 4, Thread X 4, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 5, Thread X 5, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 6, Thread X 6, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 7, Thread X 7, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 8, Thread X 8, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 9, Thread X 9, Calculating variance: adding (0.78 - 0.59)^2, current variance: 0.14
# Row 0, Thread X 0, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 1, Thread X 1, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 2, Thread X 2, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 3, Thread X 3, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 4, Thread X 4, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 5, Thread X 5, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 6, Thread X 6, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 7, Thread X 7, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 8, Thread X 8, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 9, Thread X 9, Calculating variance: adding (0.80 - 0.59)^2, current variance: 0.19
# Row 0, Thread X 0, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 1, Thread X 1, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 2, Thread X 2, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 3, Thread X 3, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 4, Thread X 4, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 5, Thread X 5, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 6, Thread X 6, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 7, Thread X 7, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 8, Thread X 8, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 9, Thread X 9, Calculating variance: adding (0.91 - 0.59)^2, current variance: 0.29
# Row 0, Thread X 0, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 1, Thread X 1, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 2, Thread X 2, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 3, Thread X 3, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 4, Thread X 4, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 5, Thread X 5, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 6, Thread X 6, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 7, Thread X 7, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 8, Thread X 8, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 9, Thread X 9, Calculating variance: adding (0.20 - 0.59)^2, current variance: 0.44
# Row 0, Thread X 0, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 1, Thread X 1, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 2, Thread X 2, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 3, Thread X 3, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 4, Thread X 4, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 5, Thread X 5, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 6, Thread X 6, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 7, Thread X 7, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 8, Thread X 8, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 9, Thread X 9, Calculating variance: adding (0.34 - 0.59)^2, current variance: 0.51
# Row 0, Thread X 0, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 1, Thread X 1, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 2, Thread X 2, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 3, Thread X 3, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 4, Thread X 4, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 5, Thread X 5, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 6, Thread X 6, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 7, Thread X 7, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 8, Thread X 8, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 9, Thread X 9, Calculating variance: adding (0.77 - 0.59)^2, current variance: 0.54
# Row 0, Thread X 0, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 1, Thread X 1, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 2, Thread X 2, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 3, Thread X 3, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 4, Thread X 4, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 5, Thread X 5, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 6, Thread X 6, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 7, Thread X 7, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 8, Thread X 8, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 9, Thread X 9, Calculating variance: adding (0.28 - 0.59)^2, current variance: 0.63
# Row 0, Thread X 0, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 1, Thread X 1, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 2, Thread X 2, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 3, Thread X 3, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 4, Thread X 4, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 5, Thread X 5, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 6, Thread X 6, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 7, Thread X 7, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 8, Thread X 8, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 9, Thread X 9, Calculating variance: adding (0.55 - 0.59)^2, current variance: 0.63
# Row 0, Thread X 0, Final variance: 0.06, Stddev: 0.25
# Row 1, Thread X 1, Final variance: 0.06, Stddev: 0.25
# Row 2, Thread X 2, Final variance: 0.06, Stddev: 0.25
# Row 3, Thread X 3, Final variance: 0.06, Stddev: 0.25
# Row 4, Thread X 4, Final variance: 0.06, Stddev: 0.25
# Row 5, Thread X 5, Final variance: 0.06, Stddev: 0.25
# Row 6, Thread X 6, Final variance: 0.06, Stddev: 0.25
# Row 7, Thread X 7, Final variance: 0.06, Stddev: 0.25
# Row 8, Thread X 8, Final variance: 0.06, Stddev: 0.25
# Row 9, Thread X 9, Final variance: 0.06, Stddev: 0.25
# Row 0, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 1, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 2, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 3, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 4, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 5, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 6, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 7, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 8, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 9, Thread Y 0, Normalizing shared[0]: (0.84 - 0.59) / 0.25 = 1.01
# Row 0, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 1, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 2, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 3, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 4, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 5, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 6, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 7, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 8, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 9, Thread Y 0, Normalizing shared[1]: (0.39 - 0.59) / 0.25 = -0.76
# Row 0, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 1, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 2, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 3, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 4, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 5, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 6, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 7, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 8, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 9, Thread Y 0, Normalizing shared[2]: (0.78 - 0.59) / 0.25 = 0.78
# Row 0, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 1, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 2, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 3, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 4, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 5, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 6, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 7, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 8, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 9, Thread Y 0, Normalizing shared[3]: (0.80 - 0.59) / 0.25 = 0.84
# Row 0, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 1, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 2, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 3, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 4, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 5, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 6, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 7, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 8, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 9, Thread Y 0, Normalizing shared[4]: (0.91 - 0.59) / 0.25 = 1.29
# Row 0, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 1, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 2, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 3, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 4, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 5, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 6, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 7, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 8, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 9, Thread Y 0, Normalizing shared[5]: (0.20 - 0.59) / 0.25 = -1.54
# Row 0, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 1, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 2, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 3, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 4, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 5, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 6, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 7, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 8, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 9, Thread Y 0, Normalizing shared[6]: (0.34 - 0.59) / 0.25 = -1.00
# Row 0, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 1, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 2, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 3, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 4, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 5, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 6, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 7, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 8, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 9, Thread Y 0, Normalizing shared[7]: (0.77 - 0.59) / 0.25 = 0.72
# Row 0, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 1, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 2, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 3, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 4, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 5, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 6, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 7, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 8, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 9, Thread Y 0, Normalizing shared[8]: (0.28 - 0.59) / 0.25 = -1.22
# Row 0, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 1, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 2, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 3, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 4, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 5, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 6, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 7, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 8, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# Row 9, Thread Y 0, Normalizing shared[9]: (0.55 - 0.59) / 0.25 = -0.13
# A:
# 0.84 0.39 0.78 0.80 0.91 0.20 0.34 0.77 0.28 0.55
# 0.48 0.63 0.36 0.51 0.95 0.92 0.64 0.72 0.14 0.61
# 0.02 0.24 0.14 0.80 0.16 0.40 0.13 0.11 1.00 0.22
# 0.51 0.84 0.61 0.30 0.64 0.52 0.49 0.97 0.29 0.77
# 0.53 0.77 0.40 0.89 0.28 0.35 0.81 0.92 0.07 0.95
# 0.53 0.09 0.19 0.66 0.89 0.35 0.06 0.02 0.46 0.06
# 0.24 0.97 0.90 0.85 0.27 0.54 0.38 0.76 0.51 0.67
# 0.53 0.04 0.44 0.93 0.93 0.72 0.28 0.74 0.64 0.35
# 0.69 0.17 0.44 0.88 0.83 0.33 0.23 0.89 0.35 0.69
# 0.96 0.59 0.66 0.86 0.44 0.92 0.40 0.81 0.68 0.91
#
# B:
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
# 1.01 -0.76 0.78 0.84 1.29 -1.54 -1.00 0.72 -1.22 -0.13
