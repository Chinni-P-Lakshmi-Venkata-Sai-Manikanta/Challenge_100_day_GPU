# %%
# %%writefile matrix_vec_mult.cu
# #include <iostream>
# #include <stdio.h>
#
# __global__ void vectorMatrixMult(const float* A, const float* B, float* C, int N) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#     if (i < N) {
#       float sum=0.0f;
#       for (int j = 0; j < N; j++) {
#          sum += A[i*N+j]*B[j];
#          // Add print statement inside the inner loop of the kernel
#          printf("Thread %d, row %d, col %d: A[%d][%d] * B[%d] = %.2f * %.2f = %.2f, current sum = %.2f\n",
#                 threadIdx.x, i, j, i, j, j, A[i*N+j], B[j], A[i*N+j]*B[j], sum);
#       }
#       C[i]=sum;
#       // Add print statement outside the inner loop of the kernel
#       printf("Thread %d, row %d: Final sum for C[%d] = %.2f\n", threadIdx.x, i, i, C[i]);
# }}
#
# int main() {
#     //initialize the matrix
#     const int N = 10;
#     float *A, *B, *C;
#
#     // initialize the input matrices
#     A = (float *)malloc( N*N* sizeof(float));
#     B = (float *)malloc(N*sizeof(float));
#     C = (float *)malloc(N*sizeof(float));
#
#
#     for (int i = 0; i < N; i++)
#     {
#         // Add print statement inside the outer loop (for rows) of matrix A initialization
#         printf("Initializing row %d of matrix A\n", i);
#         for (int j = 0; j < N; j++)
#         {
#             A[i * N + j] = 1.0f;
#             // Add print statement inside the inner loop (for columns) of matrix A initialization
#             printf("  Initializing element A[%d][%d] to %.2f\n", i, j, A[i * N + j]);
#         }
#         B[i] = 2.0f;
#         C[i] = 0.0f;
#         // Add print statement inside the loop for initializing vectors B and C
#         printf("Initializing element B[%d] to %.2f and C[%d] to %.2f\n", i, B[i], i, C[i]);
#     }
#
#     float *d_a, *d_b,*d_c;
#     cudaMalloc(&d_a,N*N*sizeof(float));
#     cudaMalloc(&d_b,N*sizeof(float));
#     cudaMalloc(&d_c,N*sizeof(float));
#     cudaMemcpy(d_a,A,N*N*sizeof(float),cudaMemcpyHostToDevice);
#     cudaMemcpy(d_b,B,N*sizeof(float),cudaMemcpyHostToDevice);
#     int blocksize=256;
#     int gridsize = (N + blocksize - 1) / blocksize;
#     vectorMatrixMult<<<gridsize,blocksize>>>(d_a,d_b,d_c,N);
#
#   cudaDeviceSynchronize();
# cudaMemcpy(C,d_c,N*sizeof(float),cudaMemcpyDeviceToHost);
#
#      printf("A:\n");
#     for (int i = 0; i < N; i++) {
#         for (int j = 0; j < N; j++) {
#
#             printf("%.2f ", A[i * N + j]); // Prints each element with 2 decimal precision
#         }
#         printf("\n"); // Adds a newline after each row
#     }
#
#     printf("C:\n");
#     for (int i = 0; i < N; i++) {
#
#
#             printf("%.2f ",C[i]); // Prints each element with 2 decimal precision
#
#     }
# printf("\n");
#      printf("B:\n");
#     for (int i = 0; i < N; i++) {
#
#
#             printf("%.2f ", B[i ]); // Prints each element with 2 decimal precision
#
#     }
#
#
#
#     cudaFree(d_a);
#     cudaFree(d_b);
#     cudaFree(d_c);
#
# }
# Out:
# Writing matrix_vec_mult.cu

# %%
# Compile with the specified architecture
# !nvcc matrix_vec_mult.cu -o matrix_vec_mult -gencode arch=compute_75,code=sm_75

# Run the executable
# !./matrix_vec_mult
# Out:
# Initializing row 0 of matrix A
#   Initializing element A[0][0] to 1.00
#   Initializing element A[0][1] to 1.00
#   Initializing element A[0][2] to 1.00
#   Initializing element A[0][3] to 1.00
#   Initializing element A[0][4] to 1.00
#   Initializing element A[0][5] to 1.00
#   Initializing element A[0][6] to 1.00
#   Initializing element A[0][7] to 1.00
#   Initializing element A[0][8] to 1.00
#   Initializing element A[0][9] to 1.00
# Initializing element B[0] to 2.00 and C[0] to 0.00
# Initializing row 1 of matrix A
#   Initializing element A[1][0] to 1.00
#   Initializing element A[1][1] to 1.00
#   Initializing element A[1][2] to 1.00
#   Initializing element A[1][3] to 1.00
#   Initializing element A[1][4] to 1.00
#   Initializing element A[1][5] to 1.00
#   Initializing element A[1][6] to 1.00
#   Initializing element A[1][7] to 1.00
#   Initializing element A[1][8] to 1.00
#   Initializing element A[1][9] to 1.00
# Initializing element B[1] to 2.00 and C[1] to 0.00
# Initializing row 2 of matrix A
#   Initializing element A[2][0] to 1.00
#   Initializing element A[2][1] to 1.00
#   Initializing element A[2][2] to 1.00
#   Initializing element A[2][3] to 1.00
#   Initializing element A[2][4] to 1.00
#   Initializing element A[2][5] to 1.00
#   Initializing element A[2][6] to 1.00
#   Initializing element A[2][7] to 1.00
#   Initializing element A[2][8] to 1.00
#   Initializing element A[2][9] to 1.00
# Initializing element B[2] to 2.00 and C[2] to 0.00
# Initializing row 3 of matrix A
#   Initializing element A[3][0] to 1.00
#   Initializing element A[3][1] to 1.00
#   Initializing element A[3][2] to 1.00
#   Initializing element A[3][3] to 1.00
#   Initializing element A[3][4] to 1.00
#   Initializing element A[3][5] to 1.00
#   Initializing element A[3][6] to 1.00
#   Initializing element A[3][7] to 1.00
#   Initializing element A[3][8] to 1.00
#   Initializing element A[3][9] to 1.00
# Initializing element B[3] to 2.00 and C[3] to 0.00
# Initializing row 4 of matrix A
#   Initializing element A[4][0] to 1.00
#   Initializing element A[4][1] to 1.00
#   Initializing element A[4][2] to 1.00
#   Initializing element A[4][3] to 1.00
#   Initializing element A[4][4] to 1.00
#   Initializing element A[4][5] to 1.00
#   Initializing element A[4][6] to 1.00
#   Initializing element A[4][7] to 1.00
#   Initializing element A[4][8] to 1.00
#   Initializing element A[4][9] to 1.00
# Initializing element B[4] to 2.00 and C[4] to 0.00
# Initializing row 5 of matrix A
#   Initializing element A[5][0] to 1.00
#   Initializing element A[5][1] to 1.00
#   Initializing element A[5][2] to 1.00
#   Initializing element A[5][3] to 1.00
#   Initializing element A[5][4] to 1.00
#   Initializing element A[5][5] to 1.00
#   Initializing element A[5][6] to 1.00
#   Initializing element A[5][7] to 1.00
#   Initializing element A[5][8] to 1.00
#   Initializing element A[5][9] to 1.00
# Initializing element B[5] to 2.00 and C[5] to 0.00
# Initializing row 6 of matrix A
#   Initializing element A[6][0] to 1.00
#   Initializing element A[6][1] to 1.00
#   Initializing element A[6][2] to 1.00
#   Initializing element A[6][3] to 1.00
#   Initializing element A[6][4] to 1.00
#   Initializing element A[6][5] to 1.00
#   Initializing element A[6][6] to 1.00
#   Initializing element A[6][7] to 1.00
#   Initializing element A[6][8] to 1.00
#   Initializing element A[6][9] to 1.00
# Initializing element B[6] to 2.00 and C[6] to 0.00
# Initializing row 7 of matrix A
#   Initializing element A[7][0] to 1.00
#   Initializing element A[7][1] to 1.00
#   Initializing element A[7][2] to 1.00
#   Initializing element A[7][3] to 1.00
#   Initializing element A[7][4] to 1.00
#   Initializing element A[7][5] to 1.00
#   Initializing element A[7][6] to 1.00
#   Initializing element A[7][7] to 1.00
#   Initializing element A[7][8] to 1.00
#   Initializing element A[7][9] to 1.00
# Initializing element B[7] to 2.00 and C[7] to 0.00
# Initializing row 8 of matrix A
#   Initializing element A[8][0] to 1.00
#   Initializing element A[8][1] to 1.00
#   Initializing element A[8][2] to 1.00
#   Initializing element A[8][3] to 1.00
#   Initializing element A[8][4] to 1.00
#   Initializing element A[8][5] to 1.00
#   Initializing element A[8][6] to 1.00
#   Initializing element A[8][7] to 1.00
#   Initializing element A[8][8] to 1.00
#   Initializing element A[8][9] to 1.00
# Initializing element B[8] to 2.00 and C[8] to 0.00
# Initializing row 9 of matrix A
#   Initializing element A[9][0] to 1.00
#   Initializing element A[9][1] to 1.00
#   Initializing element A[9][2] to 1.00
#   Initializing element A[9][3] to 1.00
#   Initializing element A[9][4] to 1.00
#   Initializing element A[9][5] to 1.00
#   Initializing element A[9][6] to 1.00
#   Initializing element A[9][7] to 1.00
#   Initializing element A[9][8] to 1.00
#   Initializing element A[9][9] to 1.00
# Initializing element B[9] to 2.00 and C[9] to 0.00
# Thread 0, row 0, col 0: A[0][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 1, row 1, col 0: A[1][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 2, row 2, col 0: A[2][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 3, row 3, col 0: A[3][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 4, row 4, col 0: A[4][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 5, row 5, col 0: A[5][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 6, row 6, col 0: A[6][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 7, row 7, col 0: A[7][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 8, row 8, col 0: A[8][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 9, row 9, col 0: A[9][0] * B[0] = 1.00 * 2.00 = 2.00, current sum = 2.00
# Thread 0, row 0, col 1: A[0][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 1, row 1, col 1: A[1][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 2, row 2, col 1: A[2][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 3, row 3, col 1: A[3][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 4, row 4, col 1: A[4][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 5, row 5, col 1: A[5][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 6, row 6, col 1: A[6][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 7, row 7, col 1: A[7][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 8, row 8, col 1: A[8][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 9, row 9, col 1: A[9][1] * B[1] = 1.00 * 2.00 = 2.00, current sum = 4.00
# Thread 0, row 0, col 2: A[0][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 1, row 1, col 2: A[1][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 2, row 2, col 2: A[2][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 3, row 3, col 2: A[3][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 4, row 4, col 2: A[4][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 5, row 5, col 2: A[5][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 6, row 6, col 2: A[6][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 7, row 7, col 2: A[7][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 8, row 8, col 2: A[8][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 9, row 9, col 2: A[9][2] * B[2] = 1.00 * 2.00 = 2.00, current sum = 6.00
# Thread 0, row 0, col 3: A[0][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 1, row 1, col 3: A[1][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 2, row 2, col 3: A[2][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 3, row 3, col 3: A[3][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 4, row 4, col 3: A[4][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 5, row 5, col 3: A[5][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 6, row 6, col 3: A[6][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 7, row 7, col 3: A[7][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 8, row 8, col 3: A[8][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 9, row 9, col 3: A[9][3] * B[3] = 1.00 * 2.00 = 2.00, current sum = 8.00
# Thread 0, row 0, col 4: A[0][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 1, row 1, col 4: A[1][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 2, row 2, col 4: A[2][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 3, row 3, col 4: A[3][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 4, row 4, col 4: A[4][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 5, row 5, col 4: A[5][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 6, row 6, col 4: A[6][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 7, row 7, col 4: A[7][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 8, row 8, col 4: A[8][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 9, row 9, col 4: A[9][4] * B[4] = 1.00 * 2.00 = 2.00, current sum = 10.00
# Thread 0, row 0, col 5: A[0][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 1, row 1, col 5: A[1][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 2, row 2, col 5: A[2][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 3, row 3, col 5: A[3][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 4, row 4, col 5: A[4][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 5, row 5, col 5: A[5][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 6, row 6, col 5: A[6][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 7, row 7, col 5: A[7][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 8, row 8, col 5: A[8][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 9, row 9, col 5: A[9][5] * B[5] = 1.00 * 2.00 = 2.00, current sum = 12.00
# Thread 0, row 0, col 6: A[0][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 1, row 1, col 6: A[1][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 2, row 2, col 6: A[2][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 3, row 3, col 6: A[3][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 4, row 4, col 6: A[4][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 5, row 5, col 6: A[5][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 6, row 6, col 6: A[6][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 7, row 7, col 6: A[7][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 8, row 8, col 6: A[8][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 9, row 9, col 6: A[9][6] * B[6] = 1.00 * 2.00 = 2.00, current sum = 14.00
# Thread 0, row 0, col 7: A[0][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 1, row 1, col 7: A[1][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 2, row 2, col 7: A[2][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 3, row 3, col 7: A[3][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 4, row 4, col 7: A[4][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 5, row 5, col 7: A[5][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 6, row 6, col 7: A[6][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 7, row 7, col 7: A[7][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 8, row 8, col 7: A[8][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 9, row 9, col 7: A[9][7] * B[7] = 1.00 * 2.00 = 2.00, current sum = 16.00
# Thread 0, row 0, col 8: A[0][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 1, row 1, col 8: A[1][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 2, row 2, col 8: A[2][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 3, row 3, col 8: A[3][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 4, row 4, col 8: A[4][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 5, row 5, col 8: A[5][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 6, row 6, col 8: A[6][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 7, row 7, col 8: A[7][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 8, row 8, col 8: A[8][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 9, row 9, col 8: A[9][8] * B[8] = 1.00 * 2.00 = 2.00, current sum = 18.00
# Thread 0, row 0, col 9: A[0][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 1, row 1, col 9: A[1][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 2, row 2, col 9: A[2][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 3, row 3, col 9: A[3][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 4, row 4, col 9: A[4][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 5, row 5, col 9: A[5][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 6, row 6, col 9: A[6][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 7, row 7, col 9: A[7][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 8, row 8, col 9: A[8][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 9, row 9, col 9: A[9][9] * B[9] = 1.00 * 2.00 = 2.00, current sum = 20.00
# Thread 0, row 0: Final sum for C[0] = 20.00
# Thread 1, row 1: Final sum for C[1] = 20.00
# Thread 2, row 2: Final sum for C[2] = 20.00
# Thread 3, row 3: Final sum for C[3] = 20.00
# Thread 4, row 4: Final sum for C[4] = 20.00
# Thread 5, row 5: Final sum for C[5] = 20.00
# Thread 6, row 6: Final sum for C[6] = 20.00
# Thread 7, row 7: Final sum for C[7] = 20.00
# Thread 8, row 8: Final sum for C[8] = 20.00
# Thread 9, row 9: Final sum for C[9] = 20.00
# A:
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# C:
# 20.00 20.00 20.00 20.00 20.00 20.00 20.00 20.00 20.00 20.00
# B:
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
