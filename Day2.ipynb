# %%
# %%writefile MatrixAdd.cu
# #include <iostream>
# #include <stdio.h>
#
# __global__ void MatrixAdd_C(const float* A, const float* B, float* C, int N) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if (i < N)  {
#         printf("Kernel C - Thread (%d, %d) in Block (%d, %d): i = %d\n", threadIdx.x, threadIdx.y, blockIdx.x, blockIdx.y, i);
#         for(int j=0;j<N;j++){
#           C[i*N+j] = A[i*N+j] + B[i*N+j];
#         }
#     return;
#     }
# }
#
#
#
# __global__ void MatrixAdd_B(const float* A, const float* B, float* C, int N) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#     int j = blockIdx.y * blockDim.y + threadIdx.y;
#     if ((i >= N) && (j >= N)) { return ; }
#
#     printf("Kernel B - Thread (%d, %d) in Block (%d, %d): i = %d, j = %d\n", threadIdx.x, threadIdx.y, blockIdx.x, blockIdx.y, i, j);
#     C[i*N+j] = A[i*N+j] + B[i*N+j];
#
#     }
#
# __global__ void MatrixAdd_D(const float* A, const float* B, float* C, int N) {
#     int j = blockIdx.y * blockDim.y + threadIdx.y;
#
#     if (j < N)  {
#         printf("Kernel D - Thread (%d, %d) in Block (%d, %d): j = %d\n", threadIdx.x, threadIdx.y, blockIdx.x, blockIdx.y, j);
#         for(int i=0;i<N;i++){
#
#           C[i*N+j] = A[i*N+j] + B[i*N+j];
#
#         }
#
#     }
#
# }
#
#
#
# int main() {
#     const int N = 10;
#     float *A, *B, *C;
#
#     // initialize the input matrices
#     A = (float *)malloc( N*N* sizeof(float));
#     B = (float *)malloc(N*N* sizeof(float));
#     C = (float *)malloc(N*N * sizeof(float));
#
#
#     for (int i = 0; i < N; i++)
#     {
#         for (int j = 0; j < N; j++)
#         {
#             A[i * N + j] = 1.0f;
#             B[i * N + j] = 2.0f;
#             C[i * N + j] = 0.0f;
#         }
#     }
#
#     float *d_a, *d_b,*d_c;
#     cudaMalloc((void **)&d_a,N*N*sizeof(float));
#     cudaMalloc((void **)&d_b,N*N*sizeof(float));
#     cudaMalloc((void **)&d_c,N*N*sizeof(float));
#     cudaMemcpy(d_a,A,N*N*sizeof(float),cudaMemcpyHostToDevice);
#     cudaMemcpy(d_b,B,N*N*sizeof(float),cudaMemcpyHostToDevice);
#
#     dim3 dimBlock(32, 16);
#     dim3 dimGrid(ceil(N / 32.0f), ceil(N/ 16.0f));
#     MatrixAdd_B<<<dimGrid, dimBlock>>>(d_a, d_b, d_c,N);
#     cudaDeviceSynchronize();
#
#     cudaMemcpy(C,d_c,N*N*sizeof(float),cudaMemcpyDeviceToHost);
#     printf("C:\n");
#     for (int i = 0; i < N; i++) {
#         for (int j = 0; j < N; j++) {
#
#             printf("%.2f ",C[i * N + j]); // Prints each element with 2 decimal precision
#         }
#         printf("\n"); // Adds a newline after each row
#     }
#      printf("A:\n");
#     for (int i = 0; i < N; i++) {
#         for (int j = 0; j < N; j++) {
#
#             printf("%.2f ", A[i * N + j]); // Prints each element with 2 decimal precision
#         }
#         printf("\n"); // Adds a newline after each row
#     }
#      printf("B:\n");
#     for (int i = 0; i < N; i++) {
#         for (int j = 0; j < N; j++) {
#
#             printf("%.2f ", B[i * N + j]); // Prints each element with 2 decimal precision
#         }
#         printf("\n"); // Adds a newline after each row
#     }
#     cudaFree(d_a);
#     cudaFree(d_b);
#     cudaFree(d_c);
#
# }
# Out:
# Overwriting MatrixAdd.cu

# %%
# Compile with the specified architecture
# !nvcc MatrixAdd.cu -o MatrixAdd -gencode arch=compute_75,code=sm_75

# Run the executable
# !./MatrixAdd
# Out:
# Kernel B - Thread (0, 12) in Block (0, 0): i = 0, j = 12
# Kernel B - Thread (1, 12) in Block (0, 0): i = 1, j = 12
# Kernel B - Thread (2, 12) in Block (0, 0): i = 2, j = 12
# Kernel B - Thread (3, 12) in Block (0, 0): i = 3, j = 12
# Kernel B - Thread (4, 12) in Block (0, 0): i = 4, j = 12
# Kernel B - Thread (5, 12) in Block (0, 0): i = 5, j = 12
# Kernel B - Thread (6, 12) in Block (0, 0): i = 6, j = 12
# Kernel B - Thread (7, 12) in Block (0, 0): i = 7, j = 12
# Kernel B - Thread (8, 12) in Block (0, 0): i = 8, j = 12
# Kernel B - Thread (9, 12) in Block (0, 0): i = 9, j = 12
# Kernel B - Thread (0, 13) in Block (0, 0): i = 0, j = 13
# Kernel B - Thread (1, 13) in Block (0, 0): i = 1, j = 13
# Kernel B - Thread (2, 13) in Block (0, 0): i = 2, j = 13
# Kernel B - Thread (3, 13) in Block (0, 0): i = 3, j = 13
# Kernel B - Thread (4, 13) in Block (0, 0): i = 4, j = 13
# Kernel B - Thread (5, 13) in Block (0, 0): i = 5, j = 13
# Kernel B - Thread (6, 13) in Block (0, 0): i = 6, j = 13
# Kernel B - Thread (7, 13) in Block (0, 0): i = 7, j = 13
# Kernel B - Thread (8, 13) in Block (0, 0): i = 8, j = 13
# Kernel B - Thread (9, 13) in Block (0, 0): i = 9, j = 13
# Kernel B - Thread (0, 10) in Block (0, 0): i = 0, j = 10
# Kernel B - Thread (1, 10) in Block (0, 0): i = 1, j = 10
# Kernel B - Thread (2, 10) in Block (0, 0): i = 2, j = 10
# Kernel B - Thread (3, 10) in Block (0, 0): i = 3, j = 10
# Kernel B - Thread (4, 10) in Block (0, 0): i = 4, j = 10
# Kernel B - Thread (5, 10) in Block (0, 0): i = 5, j = 10
# Kernel B - Thread (6, 10) in Block (0, 0): i = 6, j = 10
# Kernel B - Thread (7, 10) in Block (0, 0): i = 7, j = 10
# Kernel B - Thread (8, 10) in Block (0, 0): i = 8, j = 10
# Kernel B - Thread (9, 10) in Block (0, 0): i = 9, j = 10
# Kernel B - Thread (0, 11) in Block (0, 0): i = 0, j = 11
# Kernel B - Thread (1, 11) in Block (0, 0): i = 1, j = 11
# Kernel B - Thread (2, 11) in Block (0, 0): i = 2, j = 11
# Kernel B - Thread (3, 11) in Block (0, 0): i = 3, j = 11
# Kernel B - Thread (4, 11) in Block (0, 0): i = 4, j = 11
# Kernel B - Thread (5, 11) in Block (0, 0): i = 5, j = 11
# Kernel B - Thread (6, 11) in Block (0, 0): i = 6, j = 11
# Kernel B - Thread (7, 11) in Block (0, 0): i = 7, j = 11
# Kernel B - Thread (8, 11) in Block (0, 0): i = 8, j = 11
# Kernel B - Thread (9, 11) in Block (0, 0): i = 9, j = 11
# Kernel B - Thread (0, 14) in Block (0, 0): i = 0, j = 14
# Kernel B - Thread (1, 14) in Block (0, 0): i = 1, j = 14
# Kernel B - Thread (2, 14) in Block (0, 0): i = 2, j = 14
# Kernel B - Thread (3, 14) in Block (0, 0): i = 3, j = 14
# Kernel B - Thread (4, 14) in Block (0, 0): i = 4, j = 14
# Kernel B - Thread (5, 14) in Block (0, 0): i = 5, j = 14
# Kernel B - Thread (6, 14) in Block (0, 0): i = 6, j = 14
# Kernel B - Thread (7, 14) in Block (0, 0): i = 7, j = 14
# Kernel B - Thread (8, 14) in Block (0, 0): i = 8, j = 14
# Kernel B - Thread (9, 14) in Block (0, 0): i = 9, j = 14
# Kernel B - Thread (0, 15) in Block (0, 0): i = 0, j = 15
# Kernel B - Thread (1, 15) in Block (0, 0): i = 1, j = 15
# Kernel B - Thread (2, 15) in Block (0, 0): i = 2, j = 15
# Kernel B - Thread (3, 15) in Block (0, 0): i = 3, j = 15
# Kernel B - Thread (4, 15) in Block (0, 0): i = 4, j = 15
# Kernel B - Thread (5, 15) in Block (0, 0): i = 5, j = 15
# Kernel B - Thread (6, 15) in Block (0, 0): i = 6, j = 15
# Kernel B - Thread (7, 15) in Block (0, 0): i = 7, j = 15
# Kernel B - Thread (8, 15) in Block (0, 0): i = 8, j = 15
# Kernel B - Thread (9, 15) in Block (0, 0): i = 9, j = 15
# Kernel B - Thread (0, 6) in Block (0, 0): i = 0, j = 6
# Kernel B - Thread (1, 6) in Block (0, 0): i = 1, j = 6
# Kernel B - Thread (2, 6) in Block (0, 0): i = 2, j = 6
# Kernel B - Thread (3, 6) in Block (0, 0): i = 3, j = 6
# Kernel B - Thread (4, 6) in Block (0, 0): i = 4, j = 6
# Kernel B - Thread (5, 6) in Block (0, 0): i = 5, j = 6
# Kernel B - Thread (6, 6) in Block (0, 0): i = 6, j = 6
# Kernel B - Thread (7, 6) in Block (0, 0): i = 7, j = 6
# Kernel B - Thread (8, 6) in Block (0, 0): i = 8, j = 6
# Kernel B - Thread (9, 6) in Block (0, 0): i = 9, j = 6
# Kernel B - Thread (10, 6) in Block (0, 0): i = 10, j = 6
# Kernel B - Thread (11, 6) in Block (0, 0): i = 11, j = 6
# Kernel B - Thread (12, 6) in Block (0, 0): i = 12, j = 6
# Kernel B - Thread (13, 6) in Block (0, 0): i = 13, j = 6
# Kernel B - Thread (14, 6) in Block (0, 0): i = 14, j = 6
# Kernel B - Thread (15, 6) in Block (0, 0): i = 15, j = 6
# Kernel B - Thread (16, 6) in Block (0, 0): i = 16, j = 6
# Kernel B - Thread (17, 6) in Block (0, 0): i = 17, j = 6
# Kernel B - Thread (18, 6) in Block (0, 0): i = 18, j = 6
# Kernel B - Thread (19, 6) in Block (0, 0): i = 19, j = 6
# Kernel B - Thread (20, 6) in Block (0, 0): i = 20, j = 6
# Kernel B - Thread (21, 6) in Block (0, 0): i = 21, j = 6
# Kernel B - Thread (22, 6) in Block (0, 0): i = 22, j = 6
# Kernel B - Thread (23, 6) in Block (0, 0): i = 23, j = 6
# Kernel B - Thread (24, 6) in Block (0, 0): i = 24, j = 6
# Kernel B - Thread (25, 6) in Block (0, 0): i = 25, j = 6
# Kernel B - Thread (26, 6) in Block (0, 0): i = 26, j = 6
# Kernel B - Thread (27, 6) in Block (0, 0): i = 27, j = 6
# Kernel B - Thread (28, 6) in Block (0, 0): i = 28, j = 6
# Kernel B - Thread (29, 6) in Block (0, 0): i = 29, j = 6
# Kernel B - Thread (30, 6) in Block (0, 0): i = 30, j = 6
# Kernel B - Thread (31, 6) in Block (0, 0): i = 31, j = 6
# Kernel B - Thread (0, 3) in Block (0, 0): i = 0, j = 3
# Kernel B - Thread (1, 3) in Block (0, 0): i = 1, j = 3
# Kernel B - Thread (2, 3) in Block (0, 0): i = 2, j = 3
# Kernel B - Thread (3, 3) in Block (0, 0): i = 3, j = 3
# Kernel B - Thread (4, 3) in Block (0, 0): i = 4, j = 3
# Kernel B - Thread (5, 3) in Block (0, 0): i = 5, j = 3
# Kernel B - Thread (6, 3) in Block (0, 0): i = 6, j = 3
# Kernel B - Thread (7, 3) in Block (0, 0): i = 7, j = 3
# Kernel B - Thread (8, 3) in Block (0, 0): i = 8, j = 3
# Kernel B - Thread (9, 3) in Block (0, 0): i = 9, j = 3
# Kernel B - Thread (10, 3) in Block (0, 0): i = 10, j = 3
# Kernel B - Thread (11, 3) in Block (0, 0): i = 11, j = 3
# Kernel B - Thread (12, 3) in Block (0, 0): i = 12, j = 3
# Kernel B - Thread (13, 3) in Block (0, 0): i = 13, j = 3
# Kernel B - Thread (14, 3) in Block (0, 0): i = 14, j = 3
# Kernel B - Thread (15, 3) in Block (0, 0): i = 15, j = 3
# Kernel B - Thread (16, 3) in Block (0, 0): i = 16, j = 3
# Kernel B - Thread (17, 3) in Block (0, 0): i = 17, j = 3
# Kernel B - Thread (18, 3) in Block (0, 0): i = 18, j = 3
# Kernel B - Thread (19, 3) in Block (0, 0): i = 19, j = 3
# Kernel B - Thread (20, 3) in Block (0, 0): i = 20, j = 3
# Kernel B - Thread (21, 3) in Block (0, 0): i = 21, j = 3
# Kernel B - Thread (22, 3) in Block (0, 0): i = 22, j = 3
# Kernel B - Thread (23, 3) in Block (0, 0): i = 23, j = 3
# Kernel B - Thread (24, 3) in Block (0, 0): i = 24, j = 3
# Kernel B - Thread (25, 3) in Block (0, 0): i = 25, j = 3
# Kernel B - Thread (26, 3) in Block (0, 0): i = 26, j = 3
# Kernel B - Thread (27, 3) in Block (0, 0): i = 27, j = 3
# Kernel B - Thread (28, 3) in Block (0, 0): i = 28, j = 3
# Kernel B - Thread (29, 3) in Block (0, 0): i = 29, j = 3
# Kernel B - Thread (30, 3) in Block (0, 0): i = 30, j = 3
# Kernel B - Thread (31, 3) in Block (0, 0): i = 31, j = 3
# Kernel B - Thread (0, 7) in Block (0, 0): i = 0, j = 7
# Kernel B - Thread (1, 7) in Block (0, 0): i = 1, j = 7
# Kernel B - Thread (2, 7) in Block (0, 0): i = 2, j = 7
# Kernel B - Thread (3, 7) in Block (0, 0): i = 3, j = 7
# Kernel B - Thread (4, 7) in Block (0, 0): i = 4, j = 7
# Kernel B - Thread (5, 7) in Block (0, 0): i = 5, j = 7
# Kernel B - Thread (6, 7) in Block (0, 0): i = 6, j = 7
# Kernel B - Thread (7, 7) in Block (0, 0): i = 7, j = 7
# Kernel B - Thread (8, 7) in Block (0, 0): i = 8, j = 7
# Kernel B - Thread (9, 7) in Block (0, 0): i = 9, j = 7
# Kernel B - Thread (10, 7) in Block (0, 0): i = 10, j = 7
# Kernel B - Thread (11, 7) in Block (0, 0): i = 11, j = 7
# Kernel B - Thread (12, 7) in Block (0, 0): i = 12, j = 7
# Kernel B - Thread (13, 7) in Block (0, 0): i = 13, j = 7
# Kernel B - Thread (14, 7) in Block (0, 0): i = 14, j = 7
# Kernel B - Thread (15, 7) in Block (0, 0): i = 15, j = 7
# Kernel B - Thread (16, 7) in Block (0, 0): i = 16, j = 7
# Kernel B - Thread (17, 7) in Block (0, 0): i = 17, j = 7
# Kernel B - Thread (18, 7) in Block (0, 0): i = 18, j = 7
# Kernel B - Thread (19, 7) in Block (0, 0): i = 19, j = 7
# Kernel B - Thread (20, 7) in Block (0, 0): i = 20, j = 7
# Kernel B - Thread (21, 7) in Block (0, 0): i = 21, j = 7
# Kernel B - Thread (22, 7) in Block (0, 0): i = 22, j = 7
# Kernel B - Thread (23, 7) in Block (0, 0): i = 23, j = 7
# Kernel B - Thread (24, 7) in Block (0, 0): i = 24, j = 7
# Kernel B - Thread (25, 7) in Block (0, 0): i = 25, j = 7
# Kernel B - Thread (26, 7) in Block (0, 0): i = 26, j = 7
# Kernel B - Thread (27, 7) in Block (0, 0): i = 27, j = 7
# Kernel B - Thread (28, 7) in Block (0, 0): i = 28, j = 7
# Kernel B - Thread (29, 7) in Block (0, 0): i = 29, j = 7
# Kernel B - Thread (30, 7) in Block (0, 0): i = 30, j = 7
# Kernel B - Thread (31, 7) in Block (0, 0): i = 31, j = 7
# Kernel B - Thread (0, 4) in Block (0, 0): i = 0, j = 4
# Kernel B - Thread (1, 4) in Block (0, 0): i = 1, j = 4
# Kernel B - Thread (2, 4) in Block (0, 0): i = 2, j = 4
# Kernel B - Thread (3, 4) in Block (0, 0): i = 3, j = 4
# Kernel B - Thread (4, 4) in Block (0, 0): i = 4, j = 4
# Kernel B - Thread (5, 4) in Block (0, 0): i = 5, j = 4
# Kernel B - Thread (6, 4) in Block (0, 0): i = 6, j = 4
# Kernel B - Thread (7, 4) in Block (0, 0): i = 7, j = 4
# Kernel B - Thread (8, 4) in Block (0, 0): i = 8, j = 4
# Kernel B - Thread (9, 4) in Block (0, 0): i = 9, j = 4
# Kernel B - Thread (10, 4) in Block (0, 0): i = 10, j = 4
# Kernel B - Thread (11, 4) in Block (0, 0): i = 11, j = 4
# Kernel B - Thread (12, 4) in Block (0, 0): i = 12, j = 4
# Kernel B - Thread (13, 4) in Block (0, 0): i = 13, j = 4
# Kernel B - Thread (14, 4) in Block (0, 0): i = 14, j = 4
# Kernel B - Thread (15, 4) in Block (0, 0): i = 15, j = 4
# Kernel B - Thread (16, 4) in Block (0, 0): i = 16, j = 4
# Kernel B - Thread (17, 4) in Block (0, 0): i = 17, j = 4
# Kernel B - Thread (18, 4) in Block (0, 0): i = 18, j = 4
# Kernel B - Thread (19, 4) in Block (0, 0): i = 19, j = 4
# Kernel B - Thread (20, 4) in Block (0, 0): i = 20, j = 4
# Kernel B - Thread (21, 4) in Block (0, 0): i = 21, j = 4
# Kernel B - Thread (22, 4) in Block (0, 0): i = 22, j = 4
# Kernel B - Thread (23, 4) in Block (0, 0): i = 23, j = 4
# Kernel B - Thread (24, 4) in Block (0, 0): i = 24, j = 4
# Kernel B - Thread (25, 4) in Block (0, 0): i = 25, j = 4
# Kernel B - Thread (26, 4) in Block (0, 0): i = 26, j = 4
# Kernel B - Thread (27, 4) in Block (0, 0): i = 27, j = 4
# Kernel B - Thread (28, 4) in Block (0, 0): i = 28, j = 4
# Kernel B - Thread (29, 4) in Block (0, 0): i = 29, j = 4
# Kernel B - Thread (30, 4) in Block (0, 0): i = 30, j = 4
# Kernel B - Thread (31, 4) in Block (0, 0): i = 31, j = 4
# Kernel B - Thread (0, 8) in Block (0, 0): i = 0, j = 8
# Kernel B - Thread (1, 8) in Block (0, 0): i = 1, j = 8
# Kernel B - Thread (2, 8) in Block (0, 0): i = 2, j = 8
# Kernel B - Thread (3, 8) in Block (0, 0): i = 3, j = 8
# Kernel B - Thread (4, 8) in Block (0, 0): i = 4, j = 8
# Kernel B - Thread (5, 8) in Block (0, 0): i = 5, j = 8
# Kernel B - Thread (6, 8) in Block (0, 0): i = 6, j = 8
# Kernel B - Thread (7, 8) in Block (0, 0): i = 7, j = 8
# Kernel B - Thread (8, 8) in Block (0, 0): i = 8, j = 8
# Kernel B - Thread (9, 8) in Block (0, 0): i = 9, j = 8
# Kernel B - Thread (10, 8) in Block (0, 0): i = 10, j = 8
# Kernel B - Thread (11, 8) in Block (0, 0): i = 11, j = 8
# Kernel B - Thread (12, 8) in Block (0, 0): i = 12, j = 8
# Kernel B - Thread (13, 8) in Block (0, 0): i = 13, j = 8
# Kernel B - Thread (14, 8) in Block (0, 0): i = 14, j = 8
# Kernel B - Thread (15, 8) in Block (0, 0): i = 15, j = 8
# Kernel B - Thread (16, 8) in Block (0, 0): i = 16, j = 8
# Kernel B - Thread (17, 8) in Block (0, 0): i = 17, j = 8
# Kernel B - Thread (18, 8) in Block (0, 0): i = 18, j = 8
# Kernel B - Thread (19, 8) in Block (0, 0): i = 19, j = 8
# Kernel B - Thread (20, 8) in Block (0, 0): i = 20, j = 8
# Kernel B - Thread (21, 8) in Block (0, 0): i = 21, j = 8
# Kernel B - Thread (22, 8) in Block (0, 0): i = 22, j = 8
# Kernel B - Thread (23, 8) in Block (0, 0): i = 23, j = 8
# Kernel B - Thread (24, 8) in Block (0, 0): i = 24, j = 8
# Kernel B - Thread (25, 8) in Block (0, 0): i = 25, j = 8
# Kernel B - Thread (26, 8) in Block (0, 0): i = 26, j = 8
# Kernel B - Thread (27, 8) in Block (0, 0): i = 27, j = 8
# Kernel B - Thread (28, 8) in Block (0, 0): i = 28, j = 8
# Kernel B - Thread (29, 8) in Block (0, 0): i = 29, j = 8
# Kernel B - Thread (30, 8) in Block (0, 0): i = 30, j = 8
# Kernel B - Thread (31, 8) in Block (0, 0): i = 31, j = 8
# Kernel B - Thread (0, 0) in Block (0, 0): i = 0, j = 0
# Kernel B - Thread (1, 0) in Block (0, 0): i = 1, j = 0
# Kernel B - Thread (2, 0) in Block (0, 0): i = 2, j = 0
# Kernel B - Thread (3, 0) in Block (0, 0): i = 3, j = 0
# Kernel B - Thread (4, 0) in Block (0, 0): i = 4, j = 0
# Kernel B - Thread (5, 0) in Block (0, 0): i = 5, j = 0
# Kernel B - Thread (6, 0) in Block (0, 0): i = 6, j = 0
# Kernel B - Thread (7, 0) in Block (0, 0): i = 7, j = 0
# Kernel B - Thread (8, 0) in Block (0, 0): i = 8, j = 0
# Kernel B - Thread (9, 0) in Block (0, 0): i = 9, j = 0
# Kernel B - Thread (10, 0) in Block (0, 0): i = 10, j = 0
# Kernel B - Thread (11, 0) in Block (0, 0): i = 11, j = 0
# Kernel B - Thread (12, 0) in Block (0, 0): i = 12, j = 0
# Kernel B - Thread (13, 0) in Block (0, 0): i = 13, j = 0
# Kernel B - Thread (14, 0) in Block (0, 0): i = 14, j = 0
# Kernel B - Thread (15, 0) in Block (0, 0): i = 15, j = 0
# Kernel B - Thread (16, 0) in Block (0, 0): i = 16, j = 0
# Kernel B - Thread (17, 0) in Block (0, 0): i = 17, j = 0
# Kernel B - Thread (18, 0) in Block (0, 0): i = 18, j = 0
# Kernel B - Thread (19, 0) in Block (0, 0): i = 19, j = 0
# Kernel B - Thread (20, 0) in Block (0, 0): i = 20, j = 0
# Kernel B - Thread (21, 0) in Block (0, 0): i = 21, j = 0
# Kernel B - Thread (22, 0) in Block (0, 0): i = 22, j = 0
# Kernel B - Thread (23, 0) in Block (0, 0): i = 23, j = 0
# Kernel B - Thread (24, 0) in Block (0, 0): i = 24, j = 0
# Kernel B - Thread (25, 0) in Block (0, 0): i = 25, j = 0
# Kernel B - Thread (26, 0) in Block (0, 0): i = 26, j = 0
# Kernel B - Thread (27, 0) in Block (0, 0): i = 27, j = 0
# Kernel B - Thread (28, 0) in Block (0, 0): i = 28, j = 0
# Kernel B - Thread (29, 0) in Block (0, 0): i = 29, j = 0
# Kernel B - Thread (30, 0) in Block (0, 0): i = 30, j = 0
# Kernel B - Thread (31, 0) in Block (0, 0): i = 31, j = 0
# Kernel B - Thread (0, 9) in Block (0, 0): i = 0, j = 9
# Kernel B - Thread (1, 9) in Block (0, 0): i = 1, j = 9
# Kernel B - Thread (2, 9) in Block (0, 0): i = 2, j = 9
# Kernel B - Thread (3, 9) in Block (0, 0): i = 3, j = 9
# Kernel B - Thread (4, 9) in Block (0, 0): i = 4, j = 9
# Kernel B - Thread (5, 9) in Block (0, 0): i = 5, j = 9
# Kernel B - Thread (6, 9) in Block (0, 0): i = 6, j = 9
# Kernel B - Thread (7, 9) in Block (0, 0): i = 7, j = 9
# Kernel B - Thread (8, 9) in Block (0, 0): i = 8, j = 9
# Kernel B - Thread (9, 9) in Block (0, 0): i = 9, j = 9
# Kernel B - Thread (10, 9) in Block (0, 0): i = 10, j = 9
# Kernel B - Thread (11, 9) in Block (0, 0): i = 11, j = 9
# Kernel B - Thread (12, 9) in Block (0, 0): i = 12, j = 9
# Kernel B - Thread (13, 9) in Block (0, 0): i = 13, j = 9
# Kernel B - Thread (14, 9) in Block (0, 0): i = 14, j = 9
# Kernel B - Thread (15, 9) in Block (0, 0): i = 15, j = 9
# Kernel B - Thread (16, 9) in Block (0, 0): i = 16, j = 9
# Kernel B - Thread (17, 9) in Block (0, 0): i = 17, j = 9
# Kernel B - Thread (18, 9) in Block (0, 0): i = 18, j = 9
# Kernel B - Thread (19, 9) in Block (0, 0): i = 19, j = 9
# Kernel B - Thread (20, 9) in Block (0, 0): i = 20, j = 9
# Kernel B - Thread (21, 9) in Block (0, 0): i = 21, j = 9
# Kernel B - Thread (22, 9) in Block (0, 0): i = 22, j = 9
# Kernel B - Thread (23, 9) in Block (0, 0): i = 23, j = 9
# Kernel B - Thread (24, 9) in Block (0, 0): i = 24, j = 9
# Kernel B - Thread (25, 9) in Block (0, 0): i = 25, j = 9
# Kernel B - Thread (26, 9) in Block (0, 0): i = 26, j = 9
# Kernel B - Thread (27, 9) in Block (0, 0): i = 27, j = 9
# Kernel B - Thread (28, 9) in Block (0, 0): i = 28, j = 9
# Kernel B - Thread (29, 9) in Block (0, 0): i = 29, j = 9
# Kernel B - Thread (30, 9) in Block (0, 0): i = 30, j = 9
# Kernel B - Thread (31, 9) in Block (0, 0): i = 31, j = 9
# Kernel B - Thread (0, 5) in Block (0, 0): i = 0, j = 5
# Kernel B - Thread (1, 5) in Block (0, 0): i = 1, j = 5
# Kernel B - Thread (2, 5) in Block (0, 0): i = 2, j = 5
# Kernel B - Thread (3, 5) in Block (0, 0): i = 3, j = 5
# Kernel B - Thread (4, 5) in Block (0, 0): i = 4, j = 5
# Kernel B - Thread (5, 5) in Block (0, 0): i = 5, j = 5
# Kernel B - Thread (6, 5) in Block (0, 0): i = 6, j = 5
# Kernel B - Thread (7, 5) in Block (0, 0): i = 7, j = 5
# Kernel B - Thread (8, 5) in Block (0, 0): i = 8, j = 5
# Kernel B - Thread (9, 5) in Block (0, 0): i = 9, j = 5
# Kernel B - Thread (10, 5) in Block (0, 0): i = 10, j = 5
# Kernel B - Thread (11, 5) in Block (0, 0): i = 11, j = 5
# Kernel B - Thread (12, 5) in Block (0, 0): i = 12, j = 5
# Kernel B - Thread (13, 5) in Block (0, 0): i = 13, j = 5
# Kernel B - Thread (14, 5) in Block (0, 0): i = 14, j = 5
# Kernel B - Thread (15, 5) in Block (0, 0): i = 15, j = 5
# Kernel B - Thread (16, 5) in Block (0, 0): i = 16, j = 5
# Kernel B - Thread (17, 5) in Block (0, 0): i = 17, j = 5
# Kernel B - Thread (18, 5) in Block (0, 0): i = 18, j = 5
# Kernel B - Thread (19, 5) in Block (0, 0): i = 19, j = 5
# Kernel B - Thread (20, 5) in Block (0, 0): i = 20, j = 5
# Kernel B - Thread (21, 5) in Block (0, 0): i = 21, j = 5
# Kernel B - Thread (22, 5) in Block (0, 0): i = 22, j = 5
# Kernel B - Thread (23, 5) in Block (0, 0): i = 23, j = 5
# Kernel B - Thread (24, 5) in Block (0, 0): i = 24, j = 5
# Kernel B - Thread (25, 5) in Block (0, 0): i = 25, j = 5
# Kernel B - Thread (26, 5) in Block (0, 0): i = 26, j = 5
# Kernel B - Thread (27, 5) in Block (0, 0): i = 27, j = 5
# Kernel B - Thread (28, 5) in Block (0, 0): i = 28, j = 5
# Kernel B - Thread (29, 5) in Block (0, 0): i = 29, j = 5
# Kernel B - Thread (30, 5) in Block (0, 0): i = 30, j = 5
# Kernel B - Thread (31, 5) in Block (0, 0): i = 31, j = 5
# Kernel B - Thread (0, 2) in Block (0, 0): i = 0, j = 2
# Kernel B - Thread (1, 2) in Block (0, 0): i = 1, j = 2
# Kernel B - Thread (2, 2) in Block (0, 0): i = 2, j = 2
# Kernel B - Thread (3, 2) in Block (0, 0): i = 3, j = 2
# Kernel B - Thread (4, 2) in Block (0, 0): i = 4, j = 2
# Kernel B - Thread (5, 2) in Block (0, 0): i = 5, j = 2
# Kernel B - Thread (6, 2) in Block (0, 0): i = 6, j = 2
# Kernel B - Thread (7, 2) in Block (0, 0): i = 7, j = 2
# Kernel B - Thread (8, 2) in Block (0, 0): i = 8, j = 2
# Kernel B - Thread (9, 2) in Block (0, 0): i = 9, j = 2
# Kernel B - Thread (10, 2) in Block (0, 0): i = 10, j = 2
# Kernel B - Thread (11, 2) in Block (0, 0): i = 11, j = 2
# Kernel B - Thread (12, 2) in Block (0, 0): i = 12, j = 2
# Kernel B - Thread (13, 2) in Block (0, 0): i = 13, j = 2
# Kernel B - Thread (14, 2) in Block (0, 0): i = 14, j = 2
# Kernel B - Thread (15, 2) in Block (0, 0): i = 15, j = 2
# Kernel B - Thread (16, 2) in Block (0, 0): i = 16, j = 2
# Kernel B - Thread (17, 2) in Block (0, 0): i = 17, j = 2
# Kernel B - Thread (18, 2) in Block (0, 0): i = 18, j = 2
# Kernel B - Thread (19, 2) in Block (0, 0): i = 19, j = 2
# Kernel B - Thread (20, 2) in Block (0, 0): i = 20, j = 2
# Kernel B - Thread (21, 2) in Block (0, 0): i = 21, j = 2
# Kernel B - Thread (22, 2) in Block (0, 0): i = 22, j = 2
# Kernel B - Thread (23, 2) in Block (0, 0): i = 23, j = 2
# Kernel B - Thread (24, 2) in Block (0, 0): i = 24, j = 2
# Kernel B - Thread (25, 2) in Block (0, 0): i = 25, j = 2
# Kernel B - Thread (26, 2) in Block (0, 0): i = 26, j = 2
# Kernel B - Thread (27, 2) in Block (0, 0): i = 27, j = 2
# Kernel B - Thread (28, 2) in Block (0, 0): i = 28, j = 2
# Kernel B - Thread (29, 2) in Block (0, 0): i = 29, j = 2
# Kernel B - Thread (30, 2) in Block (0, 0): i = 30, j = 2
# Kernel B - Thread (31, 2) in Block (0, 0): i = 31, j = 2
# Kernel B - Thread (0, 1) in Block (0, 0): i = 0, j = 1
# Kernel B - Thread (1, 1) in Block (0, 0): i = 1, j = 1
# Kernel B - Thread (2, 1) in Block (0, 0): i = 2, j = 1
# Kernel B - Thread (3, 1) in Block (0, 0): i = 3, j = 1
# Kernel B - Thread (4, 1) in Block (0, 0): i = 4, j = 1
# Kernel B - Thread (5, 1) in Block (0, 0): i = 5, j = 1
# Kernel B - Thread (6, 1) in Block (0, 0): i = 6, j = 1
# Kernel B - Thread (7, 1) in Block (0, 0): i = 7, j = 1
# Kernel B - Thread (8, 1) in Block (0, 0): i = 8, j = 1
# Kernel B - Thread (9, 1) in Block (0, 0): i = 9, j = 1
# Kernel B - Thread (10, 1) in Block (0, 0): i = 10, j = 1
# Kernel B - Thread (11, 1) in Block (0, 0): i = 11, j = 1
# Kernel B - Thread (12, 1) in Block (0, 0): i = 12, j = 1
# Kernel B - Thread (13, 1) in Block (0, 0): i = 13, j = 1
# Kernel B - Thread (14, 1) in Block (0, 0): i = 14, j = 1
# Kernel B - Thread (15, 1) in Block (0, 0): i = 15, j = 1
# Kernel B - Thread (16, 1) in Block (0, 0): i = 16, j = 1
# Kernel B - Thread (17, 1) in Block (0, 0): i = 17, j = 1
# Kernel B - Thread (18, 1) in Block (0, 0): i = 18, j = 1
# Kernel B - Thread (19, 1) in Block (0, 0): i = 19, j = 1
# Kernel B - Thread (20, 1) in Block (0, 0): i = 20, j = 1
# Kernel B - Thread (21, 1) in Block (0, 0): i = 21, j = 1
# Kernel B - Thread (22, 1) in Block (0, 0): i = 22, j = 1
# Kernel B - Thread (23, 1) in Block (0, 0): i = 23, j = 1
# Kernel B - Thread (24, 1) in Block (0, 0): i = 24, j = 1
# Kernel B - Thread (25, 1) in Block (0, 0): i = 25, j = 1
# Kernel B - Thread (26, 1) in Block (0, 0): i = 26, j = 1
# Kernel B - Thread (27, 1) in Block (0, 0): i = 27, j = 1
# Kernel B - Thread (28, 1) in Block (0, 0): i = 28, j = 1
# Kernel B - Thread (29, 1) in Block (0, 0): i = 29, j = 1
# Kernel B - Thread (30, 1) in Block (0, 0): i = 30, j = 1
# Kernel B - Thread (31, 1) in Block (0, 0): i = 31, j = 1
# C:
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00 3.00
# A:
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00 1.00
# B:
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
# 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00 2.00
